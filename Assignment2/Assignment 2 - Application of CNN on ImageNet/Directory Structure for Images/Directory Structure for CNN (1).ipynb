# %%
import os
for root, dirs, files in os.walk("N:\ImageNet\Data\Validation\\"):  
    for dire in dirs:
        print(dire)
# Out:
# n01443537
# n01629819
# n01641577
# n01644900
# n01698640
# n01742172
# n01768244
# n01770393
# n01774384
# n01774750
# n01784675
# n01855672
# n01882714
# n01910747
# n01917289
# n01944390
# n01945685
# n01950731
# n01983481
# n01984695
# n02002724
# n02056570
# n02058221
# n02074367
# n02085620
# n02094433
# n02099601
# n02099712
# n02106662
# n02113799
# n02123045
# n02123394
# n02124075
# n02125311
# n02129165
# n02132136
# n02165456
# n02190166
# n02206856
# n02226429
# n02231487
# n02233338
# n02236044
# n02268443
# n02279972
# n02281406
# n02321529
# n02364673
# n02395406
# n02403003
# n02410509
# n02415577
# n02423022
# n02437312
# n02480495
# n02481823
# n02486410
# n02504458
# n02509815
# n02666196
# n02669723
# n02699494
# n02730930
# n02769748
# n02788148
# n02791270
# n02793495
# n02795169
# n02802426
# n02808440
# n02814533
# n02814860
# n02815834
# n02823428
# n02837789
# n02841315
# n02843684
# n02883205
# n02892201
# n02906734
# n02909870
# n02917067
# n02927161
# ...

# %%
#Creating the Folder Structure for removing unwanted directories including Lanczos
dir_main = "N:\ImageNet\Data\Validation\\"
int_folder = "N:\ImageNet_Data\Validation\\"    

#dir_out_main = "N:\Final_data\Validation\\"
for root, dirs, files in os.walk("N:\ImageNet\Data\Validation\\"):  
    for dire in dirs: 
        #dir_input = dir_main + str(dire) + "\lanczos\\"
        dir_output = int_folder + str(dire)
        if not os.path.exists(dir_output):
            os.makedirs(dir_output)
            print("Folder Created for Class - "  + str(dire))
# Out:
# Folder Created for Class - n01443537
# Folder Created for Class - n01629819
# Folder Created for Class - n01641577
# Folder Created for Class - n01644900
# Folder Created for Class - n01698640
# Folder Created for Class - n01742172
# Folder Created for Class - n01768244
# Folder Created for Class - n01770393
# Folder Created for Class - n01774384
# Folder Created for Class - n01774750
# Folder Created for Class - n01784675
# Folder Created for Class - n01855672
# Folder Created for Class - n01882714
# Folder Created for Class - n01910747
# Folder Created for Class - n01917289
# Folder Created for Class - n01944390
# Folder Created for Class - n01945685
# Folder Created for Class - n01950731
# Folder Created for Class - n01983481
# Folder Created for Class - n01984695
# Folder Created for Class - n02002724
# Folder Created for Class - n02056570
# Folder Created for Class - n02058221
# Folder Created for Class - n02074367
# Folder Created for Class - n02085620
# ...

# %%
#
import time
import shutil
from distutils.dir_util import copy_tree
start = time.time() 
dir_main = "N:\ImageNet\Data\Validation\\"
dir_out_main = "N:\ImageNet_Data\Validation\\"
for root, dirs, files in os.walk("N:\ImageNet\Data\Validation\\"):  
    for dire in dirs: 
        if(dire not in  ['lanczos']):
            dir_input = dir_main + str(dire) + "\lanczos\\"
            dir_output = dir_out_main + str(dire)
            #shutil.copy(dir_input, dir_output)
            copy_tree(dir_input, dir_output)
            print("Coying Images for Class : " + str(dire))
end = time.time()
print("Time for Execution: " + str(end-start))
# Out:
# Coying Images for Class : n01443537
# Coying Images for Class : n01629819
# Coying Images for Class : n01641577
# Coying Images for Class : n01644900
# Coying Images for Class : n01698640
# Coying Images for Class : n01742172
# Coying Images for Class : n01768244
# Coying Images for Class : n01770393
# Coying Images for Class : n01774384
# Coying Images for Class : n01774750
# Coying Images for Class : n01784675
# Coying Images for Class : n01855672
# Coying Images for Class : n01882714
# Coying Images for Class : n01910747
# Coying Images for Class : n01917289
# Coying Images for Class : n01944390
# Coying Images for Class : n01945685
# Coying Images for Class : n01950731
# Coying Images for Class : n01983481
# Coying Images for Class : n01984695
# Coying Images for Class : n02002724
# Coying Images for Class : n02056570
# Coying Images for Class : n02058221
# Coying Images for Class : n02074367
# Coying Images for Class : n02085620
# Coying Images for Class : n02094433
# ...

# %%
#Creating the Folder Structure for removing unwanted directories including Lanczos
#dir_main = "N:\ImageNet\Data\Validation\\"
int_folder = "N:\ImageNet_Data\Train\\"    
#dir_out_main = "N:\Final_data\Validation\\"
for root, dirs, files in os.walk("N:\ImageNet\Data\Train\\"):  
    for dire in dirs:
        if(dire not in ['images','lanczos']):
            dir_output = int_folder + str(dire)
            if not os.path.exists(dir_output):
                os.makedirs(dir_output)
                print("Folder Created for Class - "  + str(dire))
# Out:
# Folder Created for Class - n01443537
# Folder Created for Class - n01629819
# Folder Created for Class - n01641577
# Folder Created for Class - n01644900
# Folder Created for Class - n01698640
# Folder Created for Class - n01742172
# Folder Created for Class - n01768244
# Folder Created for Class - n01770393
# Folder Created for Class - n01774384
# Folder Created for Class - n01774750
# Folder Created for Class - n01784675
# Folder Created for Class - n01855672
# Folder Created for Class - n01882714
# Folder Created for Class - n01910747
# Folder Created for Class - n01917289
# Folder Created for Class - n01944390
# Folder Created for Class - n01945685
# Folder Created for Class - n01950731
# Folder Created for Class - n01983481
# Folder Created for Class - n01984695
# Folder Created for Class - n02002724
# Folder Created for Class - n02056570
# Folder Created for Class - n02058221
# Folder Created for Class - n02074367
# Folder Created for Class - n02085620
# ...

# %%
import time
import shutil
from distutils.dir_util import copy_tree
start = time.time() 
dir_main = "N:\ImageNet\Data\Train\\"
dir_out_main = "N:\ImageNet_Data\Train\\"
for root, dirs, files in os.walk("N:\ImageNet\Data\Train\\"):  
    for dire in dirs: 
        if(dire not in  ['lanczos','images']):
            dir_input = dir_main + str(dire) + "\images\lanczos\\"
            dir_output = dir_out_main + str(dire)
            #shutil.copy(dir_input, dir_output)
            copy_tree(dir_input, dir_output)
            print("Coying Images for Class : " + str(dire))
end = time.time()
print("Time for Execution: " + str(end-start))
# Out:
# Coying Images for Class : n01443537
# Coying Images for Class : n01629819
# Coying Images for Class : n01641577
# Coying Images for Class : n01644900
# Coying Images for Class : n01698640
# Coying Images for Class : n01742172
# Coying Images for Class : n01768244
# Coying Images for Class : n01770393
# Coying Images for Class : n01774384
# Coying Images for Class : n01774750
# Coying Images for Class : n01784675
# Coying Images for Class : n01855672
# Coying Images for Class : n01882714
# Coying Images for Class : n01910747
# Coying Images for Class : n01917289
# Coying Images for Class : n01944390
# Coying Images for Class : n01945685
# Coying Images for Class : n01950731
# Coying Images for Class : n01983481
# Coying Images for Class : n01984695
# Coying Images for Class : n02002724
# Coying Images for Class : n02056570
# Coying Images for Class : n02058221
# Coying Images for Class : n02074367
# Coying Images for Class : n02085620
# Coying Images for Class : n02094433
# ...
